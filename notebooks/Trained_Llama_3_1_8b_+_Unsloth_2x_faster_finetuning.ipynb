# %%
# %%capture
# !pip install unsloth "xformers==0.0.28.post2"
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"

# %% [markdown]
# * We support Llama, Mistral, Phi-3, Gemma, Yi, DeepSeek, Qwen, TinyLlama, Vicuna, Open Hermes etc
# * We support 16bit LoRA or 4bit QLoRA. Both 2x faster.
# * `max_seq_length` can be set to anything, since we do automatic RoPE Scaling via [kaiokendev's](https://kaiokendev.github.io/til) method.
# * [**NEW**] We make Gemma-2 9b / 27b **2x faster**! See our [Gemma-2 9b notebook](https://colab.research.google.com/drive/1vIrqH5uYDQwsJ4-OO3DErvuv4pBgVwk4?usp=sharing)
# * [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/drive/1WZDi7APtQ9VsvOrQSSC5DDtxq159j8iZ?usp=sharing)
# * [**NEW**] We make Mistral NeMo 12B 2x faster and fit in under 12GB of VRAM! [Mistral NeMo notebook](https://colab.research.google.com/drive/17d3U-CAIwzmbDRqbZ9NnpHxCkmXB6LZ0?usp=sharing)

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",      # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",    # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit", # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",        # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",           # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",            # Gemma 2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# ==((====))==  Unsloth 2024.11.7: Fast Llama patching. Transformers = 4.46.2.
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.564 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.0+cu121. CUDA = 8.0. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post2. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/230 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/345 [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2024.11.7 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
# Better memory management for CUDA
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the Alpaca dataset from [yahma](https://huggingface.co/datasets/yahma/alpaca-cleaned), which is a filtered version of 52K of the original [Alpaca dataset](https://crfm.stanford.edu/2023/03/13/alpaca.html). You can replace this code section with your own data prep.
#
# **[NOTE]** To train only on completions (ignoring the user's input) read TRL's docs [here](https://huggingface.co/docs/trl/sft_trainer#train-on-completions-only).
#
# **[NOTE]** Remember to add the **EOS_TOKEN** to the tokenized output!! Otherwise you'll get infinite generations!
#
# If you want to use the `llama-3` template for ShareGPT datasets, try our conversational [notebook](https://colab.research.google.com/drive/1XamvWYinY6FOSX9GLvnqSjjsNflxdhNc?usp=sharing).
#
# For text completions like novel writing, try this [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing).

# %%
from datasets import load_dataset

# Load the dataset without specifying a split
dataset = load_dataset('csv', data_files='training_data.csv', split='train')

# Split the dataset into 80% training and 20% test sets
# train_test_split = dataset['train'].train_test_split(test_size=0.2)

# Separate into training and test sets
# train_dataset = train_test_split['train']
# test_dataset = train_test_split['test']

# Define the formatting function as before
alpaca_prompt = """As a sales assistant specializing in motorcycles, your role is to provide accurate and concise answers to customer questions about motorcycle specifications, performance, and features.

BEFORE ANSWERING you must always query your knowledge base to find the motorcycle model and specs that most closely ask what is being asked.

Always follow these guidelines:

1. Provide factual and specific information about the motorcycle mentioned.
2. Use a professional and friendly tone.
3. Include units of measurement (e.g., km/h, kg, cc) in your answers.
4. If a question includes unrelated details, focus only on the motorcycle specifications.
5. Do not guess or fabricate information. If the requested specification is unavailable, state that clearly.
6. Even if you can't find the answer, you must output a response, even if it's just stating that you could not find the answer.

Here are some example responses specifically for specs and motorcycle from user queries, each seperated by a new line and dash:

---

The 豪爵 UCR100 has a maximum speed of 100 km/h.

---

The curb weight of the 豪爵 天鹰HJ125T-16D is 110.0 kg.

---

The 豪爵 虎鲨VX125 is not equipped with ABS.

---

Now, based on the following instruction and input, provide your response:

### Instruction:
{}

### Input:
{}

### Response:
{}

"""

EOS_TOKEN = tokenizer.eos_token  # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs = examples["input"]
    outputs = examples["output"]
    texts = []
    for instruction, input_text, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN to avoid infinite generation!
        text = alpaca_prompt.format(instruction, input_text, output) + EOS_TOKEN
        texts.append(text)
    return {"text": texts}

# Apply the formatting function to both the training and test sets
dataset = dataset.map(formatting_prompts_func, batched=True)
# test_dataset = test_dataset.map(formatting_prompts_func, batched=True)
test_dataset = load_dataset('csv', data_files='motorcycle_2_training_data.csv', split='train')
test_dataset = test_dataset.map(formatting_prompts_func, batched=True)
# Out:
# Map:   0%|          | 0/2360 [00:00<?, ? examples/s]

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 8,
    packing = True,
    args = TrainingArguments(
        per_device_train_batch_size=4,
        gradient_accumulation_steps=4,
        warmup_steps=50,
        num_train_epochs=3,
        learning_rate=1e-5,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps=10,
        optim="adamw_8bit",
        lr_scheduler_type="cosine",
        seed=3407,
        output_dir="outputs",
        report_to="none",
    ),
)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = NVIDIA A100-SXM4-40GB. Max memory = 39.564 GB.
# 5.984 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 6,786 | Num Epochs = 3
# O^O/ \_/ \    Batch size per device = 4 | Gradient Accumulation steps = 4
# \        /    Total batch size = 16 | Total steps = 1,272
#  "-____-"     Number of trainable parameters = 41,943,040
#     <div>
#
#       <progress value='1272' max='1272' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1272/1272 3:28:26, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.733300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.732000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.730800</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.699000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.656100</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.631900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.591100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.551200</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.504300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.448500</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.384700</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.320100</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.273700</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.245000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.229200</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.223300</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.205000</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.189400</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.182300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.178400</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.169700</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.167300</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.160000</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.155900</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.150200</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.150800</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.148300</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.150700</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.142300</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.140700</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.136100</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.138500</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.139300</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.134000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.134100</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.129600</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.131000</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.131700</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.124400</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.124200</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.129100</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.126100</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.133700</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.120500</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.121300</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.120300</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.120500</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.117300</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.118800</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.115100</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.114600</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.114500</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.114900</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.112400</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.113600</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.114200</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.112500</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.112100</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.109600</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.111300</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.110700</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.110100</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.110100</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.106500</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.106000</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.106900</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.108500</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.110100</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.107200</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.109100</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.106000</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.103500</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.102800</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.104600</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.109400</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.106100</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.103100</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.106000</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.104600</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.103500</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.105300</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.102800</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.100800</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.102700</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.110800</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.100200</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.100000</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.101700</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.099700</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.103300</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.097700</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.101100</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.099900</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.101200</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.103000</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.100700</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.097800</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.100400</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.097400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.098400</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>0.097700</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.099000</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>0.097800</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>0.097900</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.099300</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>0.100300</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>0.096400</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.099600</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>0.101500</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.098100</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.101500</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.097100</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.101800</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.097500</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.098600</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.098600</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.095600</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.097100</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>0.099200</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.098400</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>0.097500</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>0.097900</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>0.099500</td>
#     </tr>
#     <tr>
#       <td>1

# %%
#@title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 12522.3222 seconds used for training.
# 208.71 minutes used for training.
# Peak reserved memory = 13.299 GB.
# Peak reserved memory for training = 7.315 GB.
# Peak reserved memory % of max memory = 33.614 %.
# Peak reserved memory for training % of max memory = 18.489 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!
#
# **[NEW] Try 2x faster inference in a free Colab for Llama-3.1 8b Instruct [here](https://colab.research.google.com/drive/1T-YBVfnphoVc8E2E854qF3jdia2Ll2W2?usp=sharing)**

# %%
# alpaca_prompt = Copied from above

FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "What the top speed of a QJMOTOR motorcyle?",
        "",# input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 300, use_cache = True)
tokenizer.batch_decode(outputs)
# inputs = tokenizer(prompt_text, return_tensors="pt").to("cuda")
# outputs = model.generate(**inputs, max_new_tokens=2000, use_cache=True)
# response = tokenizer.decode(outputs[0], skip_special_tokens=True)
# response
# Out:
# ["<|begin_of_text|>As a sales assistant specializing in motorcycles, your role is to provide accurate and concise answers to customer questions about motorcycle specifications, performance, and features.\n\nBEFORE ANSWERING you must always query your knowledge base to find the motorcycle model and specs that most closely ask what is being asked.\n\nAlways follow these guidelines:\n\n1. Provide factual and specific information about the motorcycle mentioned.\n2. Use a professional and friendly tone.\n3. Include units of measurement (e.g., km/h, kg, cc) in your answers.\n4. If a question includes unrelated details, focus only on the motorcycle specifications.\n5. Do not guess or fabricate information. If the requested specification is unavailable, state that clearly.\n6. Even if you can't find the answer, you must output a response, even if it's just stating that you could not find the answer.\n\nHere are some example responses, each seperated by a new line and dash:\n\n---\n\nThe 豪爵 UCR100 has a maximum speed of 100 km/h.\n\n---\n\nThe curb weight of the 豪爵 天鹰HJ125T-16D is 110.0 kg.\n\n---\n\nThe 豪爵 虎鲨VX125 is not equipped with ABS.\n\n---\n\nNow, based on the following instruction and input, provide your response:\n\n### Instruction:\nWhat the top speed of a QJMOTOR motorcyle?\n\n### Input:\n\n\n### Response:\n\n\n<|end_of_text|>"]

# %% [markdown]
# ### [link text](https://) You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "Give me the specs for th 欧派 Q3",
        "", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128)
# Out:
# <|begin_of_text|>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Give me the specs for th 欧派 Q3
#
# ### Input:
#
#
# ### Response:
# The th 欧派 Q3 measures 2020x720x1070. It can go up to 95.0 km/h.<|end_of_text|>

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model") # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.json')

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# alpaca_prompt = You MUST copy from above!

inputs = tokenizer(
[
    alpaca_prompt.format(
        "What is a famous tall tower in Paris?", # instruction
        "", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128)
# Out:
# <|begin_of_text|>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# What is a famous tall tower in Paris?
#
# ### Input:
#
#
# ### Response:
# One of the most famous and iconic tall towers in Paris is the Eiffel Tower. Standing at 324 meters (1,063 feet) tall, this wrought iron tower is a symbol of the city and a must-see attraction for tourists from all over the world.<|end_of_text|>

# %% [markdown]
# You can also use Hugging Face's `AutoModelForPeftCausalLM`. Only use this if you do not have `unsloth` installed. It can be hopelessly slow, since `4bit` model downloading is not supported, and Unsloth's **inference is 2x faster**.

# %%
if False:
    # I highly do NOT suggest - use Unsloth if possible
    from peft import AutoPeftModelForCausalLM
    from transformers import AutoTokenizer
    model = AutoPeftModelForCausalLM.from_pretrained(
        "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit = load_in_4bit,
    )
    tokenizer = AutoTokenizer.from_pretrained("lora_model")

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/drive/1WZDi7APtQ9VsvOrQSSC5DDtxq159j8iZ?usp=sharing)

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "",
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in `llama.cpp` or a UI based system like `GPT4All`. You can install GPT4All by going [here](https://gpt4all.io/index.html).
#
# **[NEW] Try 2x faster inference in a free Colab for Llama-3.1 8b Instruct [here](https://colab.research.google.com/drive/1T-YBVfnphoVc8E2E854qF3jdia2Ll2W2?usp=sharing)**

# %% [markdown]
# # LangSmith Evals

# %%
# Install LangSmith and other required libraries if not already done
# !pip install langchain sentence-transformers torch langchain-openai
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.7)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.0+cu121)
# Collecting langchain-openai
#   Downloading langchain_openai-0.2.8-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.15)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.142)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.46.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.26.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Collecting langchain-core<0.4.0,>=0.3.15 (from langchain)
#   Downloading langchain_core-0.3.18-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: openai<2.0.0,>=1.54.0 in /usr/local/lib/python3.10/dist-packages (from langchain-openai) (1.54.3)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (0.7.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.54.0->langchain-openai) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Downloading langchain_openai-0.2.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.2 MB/s eta 0:00:00
# Downloading langchain_core-0.3.18-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 16.0 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.8 MB/s eta 0:00:00
# Installing collected packages: tiktoken, langchain-core, langchain-openai
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.15
#     Uninstalling langchain-core-0.3.15:
#       Successfully uninstalled langchain-core-0.3.15
# Successfully installed langchain-core-0.3.18 langchain-openai-0.2.8 tiktoken-0.8.0

# %%
import os
LANGCHAIN_TRACING_V2=True
os.environ['LANGCHAIN_ENDPOINT']="https://api.smith.langchain.com"
os.environ['LANGCHAIN_API_KEY']="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"
os.environ['LANGCHAIN_PROJECT']="ai-chatbot-for-sales"

# %%
from langchain.prompts import PromptTemplate

alpaca_test_prompt = PromptTemplate(
    input_variables=["instruction", "input"],
    template="""As a sales assistant specializing in motorcycles, your role is to provide accurate and concise answers to customer questions about motorcycle specifications, performance, and features.

BEFORE ANSWERING you must always query your knowledge base to find the motorcycle model and specs that most closely ask what is being asked.

Always follow these guidelines:

1. Provide factual and specific information about the motorcycle mentioned.
2. Use a professional and friendly tone.
3. Include units of measurement (e.g., km/h, kg, cc) in your answers.
4. If a question includes unrelated details, focus only on the motorcycle specifications.
5. Do not guess or fabricate information. If the requested specification is unavailable, state that clearly.
6. Even if you can't find the answer, you must output a response, even if it's just stating that you could not find the answer.

Here are some example responses, each seperated by a new line and dash:

---

The 豪爵 UCR100 has a maximum speed of 100 km/h.

---

The curb weight of the 豪爵 天鹰HJ125T-16D is 110.0 kg.

---

The 豪爵 虎鲨VX125 is not equipped with ABS.

---

Now, based on the following instruction and input, provide your response:

### Instruction:
{instruction}

### Input:
{input}

### Response:

"""
)

# %%
# Generate response using the custom-trained model directly
def get_llama3_response(instruction, input_text):
    prompt_text = alpaca_test_prompt.format(
        instruction=instruction,
        input=input_text
    )
    inputs = tokenizer(prompt_text, return_tensors="pt").to("cuda")
    outputs = model.generate(**inputs, max_new_tokens=150)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response.strip()

# %%
from sentence_transformers import SentenceTransformer, util
import random

# Initialize a similarity model
embedder = SentenceTransformer('all-MiniLM-L6-v2')

# Evaluate each case and log results
results = []

# Get a list of random indices
random_indices = random.sample(range(len(test_dataset)), 100)

# Iterate over the dataset using the random indices
for index in random_indices:
    sample = test_dataset[index]
    # Generate response
    response = get_llama3_response(
        sample["instruction"],
        sample["input"]
    )
    # print(f"Generated Response: {response}")

    # Pull out only what is necessary
    response_text = response.split("### Response:")[1].strip()

    # Check exact match and similarity
    exact_match = response_text == sample["output"].strip()
    embeddings = embedder.encode([response_text, sample["output"]], convert_to_tensor=True)
    similarity_score = util.pytorch_cos_sim(embeddings[0], embeddings[1]).item()
    is_correct_by_similarity = similarity_score >= 0.90

    # Store and print results
    
    results.append({
        "instruction": sample["instruction"],
        "input": sample["input"],
        "model_output": response_text,
        "expected_output": sample["output"],
        "exact_match": exact_match,
        "similarity_score": similarity_score,
        "is_correct": exact_match or is_correct_by_similarity
    })

    print(f"Instruction: {sample['instruction']}")
    print(f"Input: {sample['input']}")
    print(f"Expected Output: {sample['output']}")
    print(f"Model Output: {response_text}")
    print(f"Exact Match: {exact_match}")
    print(f"Similarity Score: {similarity_score}")
    print(f"Is Correct (Thresholded): {is_correct_by_similarity}")
    print("-" * 40)
# Out:
# Instruction: Tell me about the fuel tank capacity of the 小牛 N1S.
# Input: None
# Expected Output: The fuel tank on the 小牛 N1S holds 8.5.
# Model Output: The fuel tank on the 小牛 N1S holds 0.0.
# Exact Match: False
# Similarity Score: 0.8838831186294556
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What's the fuel tank size of the 雅迪 DE8?
# Input: Customer wants to know the main features and performance.
# Expected Output: The fuel tank on the 雅迪 DE8 holds 8.5.
# Model Output: The fuel tank on the 雅迪 DE8 holds 0.0.
# Exact Match: False
# Similarity Score: 0.8779186010360718
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What type of engine does the 钱江 风采QJ110-10C have?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 钱江 风采QJ110-10C comes with a single cylinder four stroke air-cooled  110cc engine.
# Model Output: The 钱江 风采QJ110-10C comes with a single cylinder four stroke air-cooled 110cc engine.
# Exact Match: False
# Similarity Score: 1.0
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What are the specifications of the 大运 DY125t-11?
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The 大运 DY125t-11 measures 1830x660x1100.
# Model Output: The 大运 DY125t-11 measures 1940x710x1070.
# Exact Match: False
# Similarity Score: 0.8927328586578369
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What are the engine specifications of the 飞鹰 XF150R?
# Input: None
# Expected Output: The 飞鹰 XF150R comes with a single cylinder four stroke water-cooled  150cc engine.
# Model Output: The 飞鹰 XF150R comes with a single cylinder four stroke air-cooled 150cc engine.
# Exact Match: False
# Similarity Score: 0.9750308990478516
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How fast can the 飞鹰 雅格FY110T-A go?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 飞鹰 雅格FY110T-A has a top speed of 80.0 km/h
# Model Output: The 飞鹰 雅格FY110T-A has a top speed of 85.0 km/h
# Exact Match: False
# Similarity Score: 0.9906951189041138
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Tell me about the fuel tank capacity of the 诺马 H6.
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The fuel tank on the 诺马 H6 holds 17.0.
# Model Output: The fuel tank on the 诺马 H6 holds 15.0.
# Exact Match: False
# Similarity Score: 0.9172310829162598
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How fast can the 宗申 星驰125ST go?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 宗申 星驰125ST has a top speed of 85.0 km/h
# Model Output: The 宗申 星驰125ST has a top speed of 90.0 km/h
# Exact Match: False
# Similarity Score: 0.9902116060256958
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Can you describe the engine of the 嘉陵 JH600-A?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 嘉陵 JH600-A comes with a single cylinder four stroke water-cooled  600cc engine.
# Model Output: The 嘉陵 JH600-A comes with a Not Specified engine.
# Exact Match: False
# Similarity Score: 0.732448935508728
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: Tell me about the fuel tank capacity of the 宗申 MO战.
# Input: Customer wants to know the main features and performance.
# Expected Output: The fuel tank on the 宗申 MO战 holds 5.0.
# Model Output: The fuel tank on the 宗申 MO战 holds 0.0.
# Exact Match: False
# Similarity Score: 0.9155295491218567
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What are the main features of the 大阳 天昴 DY 200-8?
# Input: None
# Expected Output: The 大阳 天昴 DY 200-8 measures 2051x818x1136.
# Model Output: The 大阳 天昴 DY 200-8 comes with a Not Specified engine.
# Exact Match: False
# Similarity Score: 0.3662714958190918
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What is the fuel capacity of the 派方 星舰6?
# Input: None
# Expected Output: The fuel tank on the 派方 星舰6 holds 20.0.
# Model Output: The fuel tank on the 派方 星舰6 holds 6.0.
# Exact Match: False
# Similarity Score: 0.8840620517730713
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: How big is the fuel tank on the 雅迪 M5?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The fuel tank on the 雅迪 M5 holds 8.5.
# Model Output: The fuel tank on the 雅迪 M5 holds 15.0.
# Exact Match: False
# Similarity Score: 0.8758493065834045
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What can you tell me about the 雅迪 DE8?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 雅迪 DE8 measures 1723x695x1240.
# Model Output: The 雅迪 DE8 measures 1890x745x1120.
# Exact Match: False
# Similarity Score: 0.9459789991378784
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What is the top speed of the 长江 Bobbie III 700i?
# Input: Customer asked about the motorcycle's speed and handling.
# Expected Output: The 长江 Bobbie III 700i has a top speed of 118.0 km/h
# Model Output: The 长江 Bobbie III 700i has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9783756732940674
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Can you describe the engine of the 大运 驰302?
# Input: None
# Expected Output: The 大运 驰302 comes with a inline dual cylinder four stroke water-cooled  300cc engine.
# Model Output: The 大运 驰302 comes with a single cylinder four stroke water-cooled 300cc engine.
# Exact Match: False
# Similarity Score: 0.9642425775527954
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What can you tell me about the 鑫源 GN太子 XY 125GY?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 鑫源 GN太子 XY 125GY measures 2040x805x1100.
# Model Output: The 鑫源 GN太子 XY 125GY measures 1830x710x1140.
# Exact Match: False
# Similarity Score: 0.9268885850906372
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How much fuel can the 派方 星雷 hold?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The fuel tank on the 派方 星雷 holds 13.0.
# Model Output: The fuel tank on the 派方 星雷 holds 6.5.
# Exact Match: False
# Similarity Score: 0.8793569803237915
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What type of engine does the 南方 NF125T-53A have?
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The 南方 NF125T-53A comes with a single cylinder four stroke air-cooled  125cc engine.
# Model Output: The 南方 NF125T-53A comes with a single cylinder four stroke air-cooled 125cc engine.
# Exact Match: False
# Similarity Score: 1.0
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What can you tell me about the 飞鹰 飞尚?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 飞鹰 飞尚 measures 1800x680x1070.
# Model Output: The 飞鹰 飞尚 measures 2000x750x1250.
# Exact Match: False
# Similarity Score: 0.9430204629898071
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What speed can the 嘉陵 巧乐 achieve?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 嘉陵 巧乐 has a top speed of 80.0 km/h
# Model Output: The 嘉陵 巧乐 has a top speed of 90.0 km/h
# Exact Match: False
# Similarity Score: 0.9728334546089172
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What are the main features of the 钱江 飞虎太子150?
# Input: Customer wants to know the main features and performance.
# Expected Output: The 钱江 飞虎太子150 measures 2120x810x1090.
# Model Output: The 钱江 飞虎太子150 measures 2120x780x1120.
# Exact Match: False
# Similarity Score: 0.9927070140838623
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What is the top speed of the 宗申 进取ZS110-60S?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 宗申 进取ZS110-60S has a top speed of 80.0 km/h
# Model Output: The 宗申 进取ZS110-60S has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9763050675392151
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Tell me the maximum speed of the 嘉陵 CoCo Cross.
# Input: None
# Expected Output: The 嘉陵 CoCo Cross has a top speed of 95.0 km/h
# Model Output: The 嘉陵 CoCo Cross has a top speed of 25.0 km/h
# Exact Match: False
# Similarity Score: 0.9744080305099487
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How big is the fuel tank on the 启典 KD150-F?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The fuel tank on the 启典 KD150-F holds 18.0.
# Model Output: The fuel tank on the 启典 KD150-F holds 0.0.
# Exact Match: False
# Similarity Score: 0.8859527111053467
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: How big is the fuel tank on the 钱江 猛龙QJ150-26H?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The fuel tank on the 钱江 猛龙QJ150-26H holds 16.0.
# Model Output: The fuel tank on the 钱江 猛龙QJ150-26H holds 0.0.
# Exact Match: False
# Similarity Score: 0.9162565469741821
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What is the fuel capacity of the 鑫源 铁甲440?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The fuel tank on the 鑫源 铁甲440 holds 14.5.
# Model Output: The fuel tank on the 鑫源 铁甲440 holds 0.0.
# Exact Match: False
# Similarity Score: 0.7816250324249268
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What engine is in the 鑫源 越能XY150-17A?
# Input: Customer wants to know the main features and performance.
# Expected Output: The 鑫源 越能XY150-17A comes with a single cylinder four stroke air-cooled  150cc engine.
# Model Output: The 鑫源 越能XY150-17A comes with a single cylinder four stroke air-cooled 150cc engine.
# Exact Match: False
# Similarity Score: 1.0
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What are the engine specifications of the 雅迪 M85?
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The 雅迪 M85 comes with a Not Specified engine.
# Model Output: The 雅迪 M85 comes with a Not Specified engine.
# Exact Match: True
# Similarity Score: 1.000000238418579
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What can you tell me about the 嘉陵 CoCo Pony 150F?
# Input: Customer wants to know the main features and performance.
# Expected Output: The 嘉陵 CoCo Pony 150F measures 1810x770x1000.
# Model Output: The 嘉陵 CoCo Pony 150F measures 2050x800x1060.
# Exact Match: False
# Similarity Score: 0.9284344911575317
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What speed can the 宗申 Z2 achieve?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 宗申 Z2 has a top speed of 93.0 km/h
# Model Output: The 宗申 Z2 has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9929640889167786
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What are the specifications of the 摩枭 500MS?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 摩枭 500MS measures 2360x860x1090.
# Model Output: The 摩枭 500MS measures 2100x805x1075.
# Exact Match: False
# Similarity Score: 0.9651472568511963
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How big is the fuel tank on the 大运 DY300-ZF?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The fuel tank on the 大运 DY300-ZF holds 14.5.
# Model Output: The fuel tank on the 大运 DY300-ZF holds 0.0.
# Exact Match: False
# Similarity Score: 0.8290978074073792
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What are the specifications of the 启典 KD200-U?
# Input: Customer wants to know the main features and performance.
# Expected Output: The 启典 KD200-U measures 1980x825x1070.
# Model Output: The 启典 KD200-U measures 2190x840x1130.
# Exact Match: False
# Similarity Score: 0.8720061779022217
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: Can you describe the engine of the 嘉陵 JH600B?
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The 嘉陵 JH600B comes with a single cylinder four stroke oil cooled  600cc engine.
# Model Output: The 嘉陵 JH600B comes with a Not Specified engine.
# Exact Match: False
# Similarity Score: 0.7291585206985474
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: Give me information about the 钱江 优悦125.
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 钱江 优悦125 measures 1990x690x1110.
# Model Output: The 钱江 优悦125 measures 1830x680x1065.
# Exact Match: False
# Similarity Score: 0.9392053484916687
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Tell me about the engine in the 嘉陵 天悦.
# Input: None
# Expected Output: The 嘉陵 天悦 comes with a single cylinder four stroke air-cooled  125cc engine.
# Model Output: The 嘉陵 天悦 comes with a single cylinder four stroke air-cooled 150cc engine.
# Exact Match: False
# Similarity Score: 0.9793170690536499
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What's the highest speed of the 摩枭 500R?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 摩枭 500R has a top speed of 120.0 km/h
# Model Output: The 摩枭 500R has a top speed of 150.0 km/h
# Exact Match: False
# Similarity Score: 0.9890827536582947
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What can you tell me about the 大阳 DY90-K?
# Input: None
# Expected Output: The 大阳 DY90-K measures 1880x750x1030.
# Model Output: The 大阳 DY90-K measures 1700x650x1000.
# Exact Match: False
# Similarity Score: 0.831995964050293
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What is the top speed of the MBP HYPE VISION?
# Input: None
# Expected Output: The MBP HYPE VISION has a top speed of 93.0 km/h
# Model Output: The MBP HYPE VISION has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9925808906555176
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What is the top speed of the 大阳 125-68M?
# Input: None
# Expected Output: The 大阳 125-68M has a top speed of 88.0 km/h
# Model Output: The 大阳 125-68M has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9823535680770874
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What's the fuel tank size of the 大运 劲动 DY 150-22 AF?
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The fuel tank on the 大运 劲动 DY 150-22 AF holds 14.0.
# Model Output: The fuel tank on the 大运 劲动 DY 150-22 AF holds 14.0.
# Exact Match: True
# Similarity Score: 1.0
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What type of engine does the 银钢 大MINI have?
# Input: None
# Expected Output: The 银钢 大MINI comes with a 150cc engine.
# Model Output: The 银钢 大MINI comes with a single cylinder four stroke air-cooled 125cc engine.
# Exact Match: False
# Similarity Score: 0.8172343969345093
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: How much fuel can the 大阳 VRS150 hold?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The fuel tank on the 大阳 VRS150 holds 10.0.
# Model Output: The fuel tank on the 大阳 VRS150 holds 0.0.
# Exact Match: False
# Similarity Score: 0.9235601425170898
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What are the main features of the 长江 CJ 650B?
# Input: None
# Expected Output: The 长江 CJ 650B measures 2235x1655x1070.
# Model Output: The 长江 CJ 650B measures 2280x900x1130.
# Exact Match: False
# Similarity Score: 0.9347859621047974
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How big is the fuel tank on the 南方 NF125T-56A?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The fuel tank on the 南方 NF125T-56A holds 0.0.
# Model Output: The fuel tank on the 南方 NF125T-56A holds 5.8.
# Exact Match: False
# Similarity Score: 0.8845311403274536
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What's the fuel tank size of the 大运 喜梦3代-DY100T-K?
# Input: Customer asked about the motorcycle's speed and handling.
# Expected Output: The fuel tank on the 大运 喜梦3代-DY100T-K holds 0.0.
# Model Output: The fuel tank on the 大运 喜梦3代-DY100T-K holds 5.0.
# Exact Match: False
# Similarity Score: 0.9131572246551514
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How fast can the 鑫源 锋刃525 go?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 鑫源 锋刃525 has a top speed of 179.0 km/h
# Model Output: The 鑫源 锋刃525 has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9607237577438354
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What are the main features of the 飞鹰 星尚?
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The 飞鹰 星尚 measures 1800x680x1070.
# Model Output: The 飞鹰 星尚 measures 2010x660x1110.
# Exact Match: False
# Similarity Score: 0.9330055713653564
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Tell me the maximum speed of the 诺马 台风太子.
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 诺马 台风太子 has a top speed of 119.0 km/h
# Model Output: The 诺马 台风太子 has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9546477794647217
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What type of engine does the 鑫源 GN太子 XY 125GY have?
# Input: Customer asked about the motorcycle's speed and handling.
# Expected Output: The 鑫源 GN太子 XY 125GY comes with a single cylinder four stroke air-cooled  125cc engine.
# Model Output: The 鑫源 GN太子 XY 125GY comes with a single cylinder four stroke air-cooled 125cc engine.
# Exact Match: False
# Similarity Score: 1.0000001192092896
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What engine is in the 宗申 新锐锋?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 宗申 新锐锋 comes with a single cylinder four stroke air-cooled  150cc engine.
# Model Output: The 宗申 新锐锋 comes with a Not Specified engine.
# Exact Match: False
# Similarity Score: 0.7225534915924072
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What is the top speed of the 钱江 骁900?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 钱江 骁900 has a top speed of 93.0 km/h
# Model Output: The 钱江 骁900 has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9923551082611084
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How much fuel can the 钱江 畅跑QJ150-11B hold?
# Input: Customer wants to know the main features and performance.
# Expected Output: The fuel tank on the 钱江 畅跑QJ150-11B holds 0.0.
# Model Output: The fuel tank on the 钱江 畅跑QJ150-11B holds 0.0.
# Exact Match: True
# Similarity Score: 1.0
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What can you tell me about the 银钢 大怪兽250?
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The 银钢 大怪兽250 measures 1980x830x1120.
# Model Output: The 银钢 大怪兽250 measures 2230x840x1170.
# Exact Match: False
# Similarity Score: 0.9154771566390991
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What is the top speed of the 大阳 VPC125?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 大阳 VPC125 has a top speed of 93.0 km/h
# Model Output: The 大阳 VPC125 has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9927321076393127
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What speed can the 宗申 V炫ZS110-53 超值型 achieve?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 宗申 V炫ZS110-53 超值型 has a top speed of 93.0 km/h
# Model Output: The 宗申 V炫ZS110-53 超值型 has a top speed of 90.0 km/h
# Exact Match: False
# Similarity Score: 0.9817632436752319
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What's the fuel tank size of the 嘉陵 好帅JL110-8A?
# Input: None
# Expected Output: The fuel tank on the 嘉陵 好帅JL110-8A holds 0.0.
# Model Output: The fuel tank on the 嘉陵 好帅JL110-8A holds 0.0.
# Exact Match: True
# Similarity Score: 0.9999999403953552
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What type of engine does the 钱江 金刚150 have?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 钱江 金刚150 comes with a single cylinder four stroke air-cooled  150cc engine.
# Model Output: The 钱江 金刚150 comes with a single cylinder four stroke air-cooled 150cc engine.
# Exact Match: False
# Similarity Score: 1.0
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Tell me about the 南方 坦克125.
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 南方 坦克125 measures 1950x770x1180.
# Model Output: The 南方 坦克125 measures 2060x770x1150.
# Exact Match: False
# Similarity Score: 0.9737937450408936
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What are the specifications of the 启典 KD150-K?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 启典 KD150-K measures 2014x750x1110.
# Model Output: The 启典 KD150-K measures 2150x870x1280.
# Exact Match: False
# Similarity Score: 0.9108046293258667
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Can you describe the engine of the 力刻 318 LK300T?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 力刻 318 LK300T comes with a single cylinder four stroke water-cooled  300cc engine.
# Model Output: The 力刻 318 LK300T comes with a single cylinder four stroke water-cooled 300cc engine.
# Exact Match: False
# Similarity Score: 1.0
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Tell me the maximum speed of the 大运 巧巧DY48QT-K.
# Input: Customer asked about the motorcycle's speed and handling.
# Expected Output: The 大运 巧巧DY48QT-K has a top speed of 80.0 km/h
# Model Output: The 大运 巧巧DY48QT-K has a top speed of 65.0 km/h
# Exact Match: False
# Similarity Score: 0.9836851358413696
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What type of engine does the 大运 C-Max 150 驰途 have?
# Input: Customer asked about the motorcycle's speed and handling.
# Expected Output: The 大运 C-Max 150 驰途 comes with a single cylinder four stroke water-cooled  150cc engine.
# Model Output: The 大运 C-Max 150 驰途 comes with a single cylinder four stroke air-cooled 150cc engine.
# Exact Match: False
# Similarity Score: 0.9752535820007324
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What's the fuel tank size of the 飞鹰 雅致?
# Input: Customer asked about the motorcycle's speed and handling.
# Expected Output: The fuel tank on the 飞鹰 雅致 holds 0.0.
# Model Output: The fuel tank on the 飞鹰 雅致 holds 10.0.
# Exact Match: False
# Similarity Score: 0.9102523922920227
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How fast can the 钱江 小飓风150i go?
# Input: None
# Expected Output: The 钱江 小飓风150i has a top speed of 99.0 km/h
# Model Output: The 钱江 小飓风150i has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9821025729179382
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What speed can the 鑫源 雪橇650 achieve?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 鑫源 雪橇650 has a top speed of 140.0 km/h
# Model Output: The 鑫源 雪橇650 has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9530390501022339
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Tell me about the fuel tank capacity of the 嘉陵 独狼JH125-C.
# Input: Customer is interested in motorcycle performance.
# Expected Output: The fuel tank on the 嘉陵 独狼JH125-C holds 0.0.
# Model Output: The fuel tank on the 嘉陵 独狼JH125-C holds 0.0.
# Exact Match: True
# Similarity Score: 1.0000001192092896
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What's the highest speed of the 鑫源 周末风400?
# Input: Customer wants to know the main features and performance.
# Expected Output: The 鑫源 周末风400 has a top speed of 100.0 km/h
# Model Output: The 鑫源 周末风400 has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9601864814758301
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What are the specifications of the 卡吉瓦 KJW700?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 卡吉瓦 KJW700 measures 2090x804x1147.
# Model Output: The 卡吉瓦 KJW700 measures 2400x1270x1200.
# Exact Match: False
# Similarity Score: 0.9037443399429321
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How big is the fuel tank on the 宗申 超悦ii代ZS150-6D?
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The fuel tank on the 宗申 超悦ii代ZS150-6D holds 0.0.
# Model Output: The fuel tank on the 宗申 超悦ii代ZS150-6D holds 0.0.
# Exact Match: True
# Similarity Score: 1.0000001192092896
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What type of engine does the 银钢 拖拖 YG175T-38 have?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 银钢 拖拖 YG175T-38 comes with a single cylinder four stroke air-cooled  175cc engine.
# Model Output: The 银钢 拖拖 YG175T-38 comes with a single cylinder four stroke water-cooled 175cc engine.
# Exact Match: False
# Similarity Score: 0.9724974632263184
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What are the main features of the 嘉陵 CoCo SVR180?
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The 嘉陵 CoCo SVR180 measures 1970x715x1070.
# Model Output: The 嘉陵 CoCo SVR180 measures 2110x810x1260.
# Exact Match: False
# Similarity Score: 0.8909100294113159
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: Tell me about the fuel tank capacity of the 钱江 SIP-125.
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The fuel tank on the 钱江 SIP-125 holds 0.0.
# Model Output: The fuel tank on the 钱江 SIP-125 holds 8.0.
# Exact Match: False
# Similarity Score: 0.9235936403274536
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How fast can the 嘉陵 ES200 go?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 嘉陵 ES200 has a top speed of 105.0 km/h
# Model Output: The 嘉陵 ES200 has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9797266125679016
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What can you tell me about the 南方 NF125T-55A?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 南方 NF125T-55A measures 1830x720x1115.
# Model Output: The 南方 NF125T-55A measures 1810x670x1110.
# Exact Match: False
# Similarity Score: 0.9581226110458374
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What speed can the 台荣 马杰斯特T3 achieve?
# Input: None
# Expected Output: The 台荣 马杰斯特T3 has a top speed of 85.0 km/h
# Model Output: The 台荣 马杰斯特T3 has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.96611487865448
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What can you tell me about the 飞鹰 维纳斯?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 飞鹰 维纳斯 measures 1860x670x1130.
# Model Output: The 飞鹰 维纳斯 measures 2000x770x1130.
# Exact Match: False
# Similarity Score: 0.8954521417617798
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What is the fuel capacity of the 大运 C-Max 150 驰途?
# Input: None
# Expected Output: The fuel tank on the 大运 C-Max 150 驰途 holds 10.5.
# Model Output: The fuel tank on the 大运 C-Max 150 驰途 holds 9.0.
# Exact Match: False
# Similarity Score: 0.9232028722763062
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How much fuel can the 飞鹰 赛格FY125T-3Y hold?
# Input: Customer wants to know the main features and performance.
# Expected Output: The fuel tank on the 飞鹰 赛格FY125T-3Y holds 4.2.
# Model Output: The fuel tank on the 飞鹰 赛格FY125T-3Y holds 0.0.
# Exact Match: False
# Similarity Score: 0.8611545562744141
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What are the main features of the 钱江 畅跑QJ125-6G?
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The 钱江 畅跑QJ125-6G measures 2025x770x1110.
# Model Output: The 钱江 畅跑QJ125-6G measures 1950x740x1065.
# Exact Match: False
# Similarity Score: 0.9516963958740234
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What engine is in the 钱江 卧龙150?
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The 钱江 卧龙150 comes with a single cylinder four stroke air-cooled  150cc engine.
# Model Output: The 钱江 卧龙150 comes with a single cylinder four stroke air-cooled 150cc engine.
# Exact Match: False
# Similarity Score: 1.0000001192092896
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What engine is in the 台荣 荣150?
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 台荣 荣150 comes with a single cylinder four stroke water-cooled  150cc engine.
# Model Output: The 台荣 荣150 comes with a Not Specified engine.
# Exact Match: False
# Similarity Score: 0.7408236265182495
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: How much fuel can the 宗申 ZS200GS hold?
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The fuel tank on the 宗申 ZS200GS holds 0.0.
# Model Output: The fuel tank on the 宗申 ZS200GS holds 0.0.
# Exact Match: True
# Similarity Score: 1.0000001192092896
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Give me information about the 银钢 铁拳 TAKKEN.
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 银钢 铁拳 TAKKEN measures 2040x838x1140.
# Model Output: The 银钢 铁拳 TAKKEN measures 2100x745x1060.
# Exact Match: False
# Similarity Score: 0.901265025138855
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How fast can the 钱江 钱江龙QJ150-19A go?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 钱江 钱江龙QJ150-19A has a top speed of 95.0 km/h
# Model Output: The 钱江 钱江龙QJ150-19A has a top speed of 100.0 km/h
# Exact Match: False
# Similarity Score: 0.9820114970207214
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: How big is the fuel tank on the 鑫源 X-Tricker魔术师?
# Input: Customer asked about the motorcycle's speed and handling.
# Expected Output: The fuel tank on the 鑫源 X-Tricker魔术师 holds 7.5.
# Model Output: The fuel tank on the 鑫源 X-Tricker魔术师 holds 9.0.
# Exact Match: False
# Similarity Score: 0.8646864295005798
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What is the top speed of the 诺马 天蝎500?
# Input: None
# Expected Output: The 诺马 天蝎500 has a top speed of 173.0 km/h
# Model Output: The 诺马 天蝎500 has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.958566427230835
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What engine is in the 嘉陵 铁悍JH125-7B?
# Input: Customer asked about the motorcycle's speed and handling.
# Expected Output: The 嘉陵 铁悍JH125-7B comes with a 125cc engine.
# Model Output: The 嘉陵 铁悍JH125-7B comes with a single cylinder four stroke air-cooled 125cc engine.
# Exact Match: False
# Similarity Score: 0.7855570912361145
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What engine is in the 宗申 ZS125-55S?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 宗申 ZS125-55S comes with a single cylinder four stroke air-cooled  125cc engine.
# Model Output: The 宗申 ZS125-55S comes with a single cylinder four stroke air-cooled 125cc engine.
# Exact Match: False
# Similarity Score: 1.0
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Give me information about the 钱江 MT 150.
# Input: None
# Expected Output: The 钱江 MT 150 measures 1990x720x1140.
# Model Output: The 钱江 MT 150 measures 2090x770x1150.
# Exact Match: False
# Similarity Score: 0.9495759010314941
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What speed can the 小牛 O achieve?
# Input: Customer asked about the motorcycle's speed and handling.
# Expected Output: The 小牛 O has a top speed of 45.0 km/h
# Model Output: The 小牛 O has a top speed of 25.0 km/h
# Exact Match: False
# Similarity Score: 0.9746729135513306
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Tell me the maximum speed of the 钱江 超金钢QJ150-25.
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The 钱江 超金钢QJ150-25 has a top speed of 100.0 km/h
# Model Output: The 钱江 超金钢QJ150-25 has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9770557880401611
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What's the fuel tank size of the MBP Finder T250X?
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The fuel tank on the MBP Finder T250X holds 0.0.
# Model Output: The fuel tank on the MBP Finder T250X holds 15.0.
# Exact Match: False
# Similarity Score: 0.8976233005523682
# Is Correct (Thresholded): False
# ----------------------------------------
# Instruction: What are the engine specifications of the 飞鹰 喜劲FY125T-3J?
# Input: None
# Expected Output: The 飞鹰 喜劲FY125T-3J comes with a single cylinder four stroke air-cooled  125cc engine.
# Model Output: The 飞鹰 喜劲FY125T-3J comes with a single cylinder four stroke air-cooled 125cc engine.
# Exact Match: False
# Similarity Score: 1.0
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: What's the highest speed of the 宗申 新创业?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 宗申 新创业 has a top speed of 93.0 km/h
# Model Output: The 宗申 新创业 has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9925853610038757
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Tell me the maximum speed of the 飞鹰 剑侠.
# Input: Customer is looking for an overview of the motorcycle.
# Expected Output: The 飞鹰 剑侠 has a top speed of 85.0 km/h
# Model Output: The 飞鹰 剑侠 has a top speed of 95.0 km/h
# Exact Match: False
# Similarity Score: 0.9623557925224304
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Can you describe the engine of the 摩枭 英伦玛莎 Divine 150?
# Input: Customer requested details on fuel and engine specs.
# Expected Output: The 摩枭 英伦玛莎 Divine 150 comes with a single cylinder four stroke water-cooled  150cc engine.
# Model Output: The 摩枭 英伦玛莎 Divine 150 comes with a single cylinder four stroke air-cooled 150cc engine.
# Exact Match: False
# Similarity Score: 0.976815938949585
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Can you describe the engine of the 大阳 VRS125?
# Input: None
# Expected Output: The 大阳 VRS125 comes with a single cylinder four stroke water-cooled  125cc engine.
# Model Output: The 大阳 VRS125 comes with a single cylinder four stroke air-cooled 125cc engine.
# Exact Match: False
# Similarity Score: 0.9747142791748047
# Is Correct (Thresholded): True
# ----------------------------------------
# Instruction: Tell me the maximum speed of the 小牛 GOVA G6T.
# Input: Customer is interested in motorcycle performance.
# Expected Output: The 小牛 GOVA G6T has a top speed of 93.0 km/h
# Model Output: The 小牛 GOVA G6T has a top speed of 90.0 km/h
# Exact Match: False
# Similarity Score: 0.9865373969078064
# Is Correct (Thresholded): True
# ----------------------------------------

# %%
import pandas as pd

# Convert to DataFrame for analysis
results_df = pd.DataFrame(results)

# Calculate summary statistics
exact_match_accuracy = results_df['exact_match'].mean()
overall_accuracy = results_df['is_correct'].mean()

print("Exact Match Accuracy:", exact_match_accuracy)
print("Overall Accuracy (including similarity):", overall_accuracy)
# Out:
# Exact Match Accuracy: 0.07
# Overall Accuracy (including similarity): 0.76
