# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/millionairemacmillionairemac/Developer/anbin-bao-ai-sales-bot-llama-3/env/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /Users/millionairemacmillionairemac/Developer/anbin-bao-ai-sales-bot-llama-3/env/lib/python3.11/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/millionairemacmillionairemac/Developer/anbin-bao-ai-sales-bot-llama-3/env/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/millionairemacmillionairemac/Developer/anbin-bao-ai-sales-bot-llama-3/env/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/millionairemacmillionairemac/Developer/anbin-bao-ai-sales-bot-llama-3/env/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/millionairemacmillionairemac/Developer/anbin-bao-ai-sales-bot-llama-3/env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Import necessary libraries
import pandas as pd
import os

# Read the CSV file
# Read all motorcycle CSV files
csv_files = [f for f in os.listdir('../data/formatted/') if f.startswith('motorcycle') and f.endswith('.csv')]
dfs = []
for file in csv_files:
    df_temp = pd.read_csv(f'../data/formatted/{file}')
    dfs.append(df_temp)
    
# Combine all dataframes
df = pd.concat(dfs, ignore_index=True)

# Display first few rows to verify data loading
print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (3265, 22)
#              Reference Price (Yuan)     Brand          Model  \
# 0                               NaN       NaN            NaN
# 1  Currently no quotation available  titanium          pedal
# 2  Currently no quotation available  titanium          pedal
# 3  Currently no quotation available  titanium          pedal
# 4  Currently no quotation available  titanium  , street car,
#
#   Production Method Origin                                           Engine  \
# 0               NaN    NaN                                              NaN
# 1               NaN    NaN  single cylinder four stroke water-cooled  150cc
# 2               NaN    NaN  single cylinder four stroke water-cooled  150cc
# 3               NaN    NaN  single cylinder four stroke water-cooled  300cc
# 4               NaN    NaN         inline dual cylinder water-cooled  250cc
#
#    Max Horsepower (Ps) Max Power/Speed (kW/rpm)  Max Torque/Speed (N·m/rpm)  \
# 0                  NaN                      NaN                         NaN
# 1                 15.8                11.6/8500                         NaN
# 2                 15.8                11.6/8500                         NaN
# 3                 25.2                18.5/8250                         NaN
# 4                 32.6                  24/9500                         NaN
#
#                                         Transmission  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2  CVT continuously variable transmission automat...  ...
# 3  CVT continuously variable transmission automat...  ...
# 4                                                  -  ...
#
#   Dimensions (LxWxH mm) Seat Height (mm) Curb Weight (kg)  \
# 0                   NaN              NaN              NaN
# 1         1970x770x1150            765.0            136.0
# 2         1920x740x1120            785.0            130.0
# 3         1900x790x1200            775.0            150.0
# 4         2100x805x1060            710.0            168.0
#
#    Fuel Tank Capacity (L)  Max Speed (km/h)  \
# 0                     NaN               NaN
# 1                     8.0             105.0
# 2                     8.0             100.0
# 3                    11.0             118.0
# 4                    13.0             120.0
#
#    Official Average Fuel Consumption (L/100km)  \
# 0                                          NaN
# 1                                            -
# 2                                            -
# 3                                            -
# 4                                            -
#
#    Measured Average Fuel Consumption (L/100km) Range (km)  Warranty  \
# 0                                          NaN        NaN       NaN
# 1                                          NaN          -       NaN
# 2                                          NaN          -       NaN
# 3                                          NaN          -       NaN
# 4                                          NaN          -       NaN
#
#           Available Colors
# 0                      NaN
# 1                      NaN
# 2  Titanium Extreme Silver
# 3         Dark Night Black
# 4  Titanium Extreme Silver
#
# [5 rows x 22 columns]

# %%
# Clean string data by removing leading/trailing whitespace and special characters
def clean_string(value):
    if pd.isna(value) or not isinstance(value, str):
        return value
    # Remove leading/trailing whitespace
    value = value.strip()
    # Remove leading/trailing commas, dots, and other common special characters
    value = value.strip('.,;:\"\'')
    # Replace multiple spaces with single space
    value = ' '.join(value.split())
    return value

# Apply cleaning to all string (object) columns
for column in df.select_dtypes(include=['object']).columns:
    df[column] = df[column].apply(clean_string)
    
    # Print a sample of changes made (first 5 changes)
    mask = df[column] != df[column].apply(lambda x: x if pd.isna(x) else x.strip())
    if mask.any():
        print(f"\nCleaning results for {column}:")
        changes = pd.DataFrame({
            'Before': df[column][mask],
            'After': df[column].apply(lambda x: x if pd.isna(x) else x.strip())[mask]
        })
        print(changes.head())

# Remove any rows that are completely empty (all values are NaN)
initial_rows = len(df)
df = df.dropna(how='all')
rows_removed = initial_rows - len(df)
if rows_removed > 0:
    print(f"\nRemoved {rows_removed} completely empty rows")

print("\nCleaning complete!")
# Out:
# Cleaning results for Reference Price (Yuan):
#     Before After
# 0      NaN   NaN
# 38     NaN   NaN
# 120    NaN   NaN
# 121    NaN   NaN
# 123    NaN   NaN
#
# Cleaning results for Brand:
#     Before After
# 0      NaN   NaN
# 123    NaN   NaN
# 124    NaN   NaN
# 125    NaN   NaN
# 127    NaN   NaN
#
# Cleaning results for Model:
#     Before After
# 0      NaN   NaN
# 60     NaN   NaN
# 106    NaN   NaN
# 107    NaN   NaN
# 108    NaN   NaN
#
# Cleaning results for Production Method:
#   Before After
# 0    NaN   NaN
# 1    NaN   NaN
# 2    NaN   NaN
# 3    NaN   NaN
# 4    NaN   NaN
#
# Cleaning results for Origin:
#   Before After
# 0    NaN   NaN
# 1    NaN   NaN
# 2    NaN   NaN
# 3    NaN   NaN
# 4    NaN   NaN
#
# Cleaning results for Engine:
#    Before After
# 0     NaN   NaN
# 23    NaN   NaN
# 44    NaN   NaN
# 77    NaN   NaN
# 78    NaN   NaN
#
# Cleaning results for Max Power/Speed (kW/rpm):
#    Before After
# 0     NaN   NaN
# 23    NaN   NaN
# 44    NaN   NaN
# 63    NaN   NaN
# 77    NaN   NaN
#
# Cleaning results for Transmission:
#    Before After
# 0     NaN   NaN
# 1     NaN   NaN
# 23    NaN   NaN
# 44    NaN   NaN
# 77    NaN   NaN
#
# Cleaning results for ABS:
#    Before After
# 7     NaN   NaN
# 18    NaN   NaN
# 19    NaN   NaN
# 20    NaN   NaN
# 22    NaN   NaN
#
# Cleaning results for Dimensions (LxWxH mm):
#    Before After
# 0     NaN   NaN
# 6     NaN   NaN
# 23    NaN   NaN
# 44    NaN   NaN
# 85    NaN   NaN
#
# Cleaning results for Official Average Fuel Consumption (L/100km):
#    Before After
# 0     NaN   NaN
# 23    NaN   NaN
# 44    NaN   NaN
# 77    NaN   NaN
# 78    NaN   NaN
#
# Cleaning results for Range (km):
#      Before After
# 0       NaN   NaN
# 661     NaN   NaN
# 1320    NaN   NaN
# 1979    NaN   NaN
# 2603    NaN   NaN
#
# Cleaning results for Warranty:
#   Before After
# 0    NaN   NaN
# 1    NaN   NaN
# 2    NaN   NaN
# 3    NaN   NaN
# 4    NaN   NaN
#
# Cleaning results for Available Colors:
#    Before After
# 0     NaN   NaN
# 1     NaN   NaN
# 6     NaN   NaN
# 10    NaN   NaN
# 11    NaN   NaN
#
# Cleaning complete!

# %%
# Get total number of rows in the dataset
print(f"\nTotal number of rows: {len(df)}")

# Calculate and display number of NaN values for each column
nan_counts = df.isna().sum()
print("\nNumber of NaN values per column:")
print(nan_counts)

# Calculate percentage of NaN values
nan_percentages = (df.isna().sum() / len(df)) * 100
print("\nPercentage of NaN values per column:")
print(nan_percentages.round(2))
# Out:
# Total number of rows: 3265
#
# Number of NaN values per column:
# Reference Price (Yuan)                          539
# Brand                                            42
# Model                                           218
# Production Method                              2246
# Origin                                         2215
# Engine                                          494
# Max Horsepower (Ps)                            1010
# Max Power/Speed (kW/rpm)                        999
# Max Torque/Speed (N·m/rpm)                     3265
# Transmission                                    472
# ABS                                             704
# CBS                                               0
# Dimensions (LxWxH mm)                           690
# Seat Height (mm)                               1434
# Curb Weight (kg)                               1111
# Fuel Tank Capacity (L)                          459
# Max Speed (km/h)                               1343
# Official Average Fuel Consumption (L/100km)     459
# Measured Average Fuel Consumption (L/100km)    3265
# Range (km)                                        5
# Warranty                                       3088
# Available Colors                               2314
# dtype: int64
#
# Percentage of NaN values per column:
# Reference Price (Yuan)                          16.51
# Brand                                            1.29
# Model                                            6.68
# Production Method                               68.79
# Origin                                          67.84
# Engine                                          15.13
# Max Horsepower (Ps)                             30.93
# Max Power/Speed (kW/rpm)                        30.60
# Max Torque/Speed (N·m/rpm)                     100.00
# Transmission                                    14.46
# ABS                                             21.56
# CBS                                              0.00
# Dimensions (LxWxH mm)                           21.13
# Seat Height (mm)                                43.92
# Curb Weight (kg)                                34.03
# Fuel Tank Capacity (L)                          14.06
# Max Speed (km/h)                                41.13
# Official Average Fuel Consumption (L/100km)     14.06
# Measured Average Fuel Consumption (L/100km)    100.00
# Range (km)                                       0.15
# Warranty                                        94.58
# Available Colors                                70.87
# dtype: float64

# %%
# Drop columns with more than 90% NaN values
threshold = 0.9  # 90% threshold
columns_to_drop = nan_percentages[nan_percentages > 90].index
df = df.drop(columns=columns_to_drop)

# Remove rows where price is NaN
price_col = 'Reference Price (Yuan)'
initial_rows = len(df)
df = df.dropna(subset=[price_col])
rows_removed = initial_rows - len(df)
print(f"\nRemoved {rows_removed} rows with missing price values")

# Replace brand values less than 3 characters with 'Not Specified'
df.loc[df['Brand'].fillna('').str.len() < 3, 'Brand'] = 'Not Specified'

# Capitalize model values
df['Model'] = df['Model'].str.capitalize()


print("\nColumns dropped due to >90% missing values:")
print(columns_to_drop.tolist())

print("\nRemaining columns:")
print(df.columns.tolist())
# Out:
# Removed 539 rows with missing price values
#
# Columns dropped due to >90% missing values:
# ['Max Torque/Speed (N·m/rpm)', 'Measured Average Fuel Consumption (L/100km)', 'Warranty']
#
# Remaining columns:
# ['Reference Price (Yuan)', 'Brand', 'Model', 'Production Method', 'Origin', 'Engine', 'Max Horsepower (Ps)', 'Max Power/Speed (kW/rpm)', 'Transmission', 'ABS', 'CBS', 'Dimensions (LxWxH mm)', 'Seat Height (mm)', 'Curb Weight (kg)', 'Fuel Tank Capacity (L)', 'Max Speed (km/h)', 'Official Average Fuel Consumption (L/100km)', 'Range (km)', 'Available Colors']

# %%
# Get detailed info about remaining columns
print("Detailed analysis of remaining features:")
for column in full_df.columns:
    nan_pct = (full_df[column].isna().sum() / len(full_df)) * 100
    unique_vals = full_df[column].nunique()
    dtype = full_df[column].dtype
    
    print(f"\n{column}:")
    print(f"Missing values: {nan_pct:.2f}%")
    print(f"Data type: {dtype}")
    print(f"Number of unique values: {unique_vals}")
    if dtype in ['object', 'category']:
        print("Top 5 most common values:")
        print(full_df[column].value_counts().head())
    elif dtype in ['int64', 'float64']:
        print(f"Mean: {full_df[column].mean():.2f}")
        print(f"Median: {full_df[column].median():.2f}")
# Out:
# Detailed analysis of remaining features:
#
# Reference Price (Yuan):
# Missing values: 16.51%
# Data type: object
# Number of unique values: 681
# Top 5 most common values:
# Reference Price (Yuan)
# Currently no quotation available    791
# 7980                                 46
# 6980                                 41
# 8980                                 28
# 23800                                23
# Name: count, dtype: int64
#
# Brand:
# Missing values: 1.29%
# Data type: object
# Number of unique values: 281
# Top 5 most common values:
# Brand
# Haojue       108
# Zongshen      96
# Guangyang     95
# BIMOTA        85
# Benelli       79
# Name: count, dtype: int64
#
# Model:
# Missing values: 6.68%
# Data type: object
# Number of unique values: 15
# Top 5 most common values:
# Model
# pedal                    1234
# street car                521
# Cruising Crown Prince     239
# Off road                  190
# Retro                     171
# Name: count, dtype: int64
#
# Production Method:
# Missing values: 68.79%
# Data type: object
# Number of unique values: 5
# Top 5 most common values:
# Production Method
# Domestic    681
# s           116
# Imported    110
# imported    107
# Joint         5
# Name: count, dtype: int64
#
# Origin:
# Missing values: 67.84%
# Data type: object
# Number of unique values: 140
# Top 5 most common values:
# Origin
# Zhejiang Qianjiang Motorcycle Co                           102
# Changzhou Guangyang Motorcycle Co                           33
# Zhuzhou Nanfang Motorcycle Co                               31
# Chongqing Zongshen Locomotive Industry Manufacturing Co     30
# Guangdong Daye Motorcycle Technology Co                     30
# Name: count, dtype: int64
#
# Engine:
# Missing values: 15.13%
# Data type: object
# Number of unique values: 432
# Top 5 most common values:
# Engine
# single cylinder four stroke air-cooled 125cc      499
# single cylinder four stroke air-cooled 150cc      264
# single cylinder four stroke water-cooled 150cc    187
# single cylinder four stroke air-cooled 110cc      131
# single cylinder four stroke water-cooled 250cc     93
# Name: count, dtype: int64
#
# Max Horsepower (Ps):
# Missing values: 30.93%
# Data type: float64
# Number of unique values: 320
# Mean: 22.05
# Median: 12.20
#
# Max Power/Speed (kW/rpm):
# Missing values: 30.60%
# Data type: object
# Number of unique values: 669
# Top 5 most common values:
# Max Power/Speed (kW/rpm)
# 0.4/        110
# 5.2/         75
# 5.2/7500     35
# 8.3/8000     35
# 6.8/7500     33
# Name: count, dtype: int64
#
# Transmission:
# Missing values: 14.46%
# Data type: object
# Number of unique values: 43
# Top 5 most common values:
# Transmission
# -                                                                1313
# CVT continuously variable transmission automatic transmission     606
# international 6-speed                                             492
# international 5-speed                                             147
# cycle 4-speed                                                      31
# Name: count, dtype: int64
#
# ABS:
# Missing values: 21.56%
# Data type: object
# Number of unique values: 8
# Top 5 most common values:
# ABS
# -           1410
# standard     770
# none         368
# not            6
# comes          3
# Name: count, dtype: int64
#
# CBS:
# Missing values: 0.00%
# Data type: object
# Number of unique values: 6
# Top 5 most common values:
# CBS
# -           2647
# without      428
# standard     161
# no            24
# optional       4
# Name: count, dtype: int64
#
# Dimensions (LxWxH mm):
# Missing values: 21.13%
# Data type: object
# Number of unique values: 2050
# Top 5 most common values:
# Dimensions (LxWxH mm)
# 216x80x1050      11
# 2040             10
# 218x80x1080       8
# 2165x805x1225     8
# 2050              6
# Name: count, dtype: int64
#
# Seat Height (mm):
# Missing values: 43.92%
# Data type: float64
# Number of unique values: 140
# Mean: 771.22
# Median: 770.00
#
# Curb Weight (kg):
# Missing values: 34.03%
# Data type: float64
# Number of unique values: 275
# Mean: 145.25
# Median: 130.00
#
# Fuel Tank Capacity (L):
# Missing values: 14.06%
# Data type: float64
# Number of unique values: 156
# Mean: 8.98
# Median: 8.50
#
# Max Speed (km/h):
# Missing values: 41.13%
# Data type: float64
# Number of unique values: 128
# Mean: 102.41
# Median: 94.00
#
# Official Average Fuel Consumption (L/100km):
# Missing values: 14.06%
# Data type: object
# Number of unique values: 114
# Top 5 most common values:
# Official Average Fuel Consumption (L/100km)
# -      2111
# 2        91
# 2.5      75
# 2.2      47
# 2.3      41
# Name: count, dtype: int64
#
# Range (km):
# Missing values: 0.15%
# Data type: object
# Number of unique values: 98
# Top 5 most common values:
# Range (km)
# -      2775
# 400      44
# 500      37
# 300      31
# 100      26
# Name: count, dtype: int64
#
# Available Colors:
# Missing values: 70.87%
# Data type: object
# Number of unique values: 883
# Top 5 most common values:
# Available Colors
# white, silver, blue, black, red    8
# gray                               6
# green, red, white, black           5
# black, red, white, blue, gray      4
# black, white, red                  4
# Name: count, dtype: int64

# %%
# Create copy of dataframe for imputation
df_imputed = df.copy()

# 1. Identify price-related columns and tech spec columns
price_columns = [col for col in df_imputed.select_dtypes(include=['int64', 'float64']).columns 
                 if 'price' in col.lower()]
tech_spec_columns = [col for col in df_imputed.select_dtypes(include=['int64', 'float64']).columns 
                    if col not in price_columns]

# 2. Impute prices with median and create flag columns
for col in price_columns:
    # Create flag column before imputation
    df_imputed[f'{col}_is_imputed'] = df_imputed[col].isna()
    # Perform imputation
    df_imputed[col] = df_imputed[col].fillna(df_imputed[col].median())

# 3. Impute technical specifications with median and create flag columns
for col in tech_spec_columns:
    # Create flag column before imputation
    df_imputed[f'{col}_is_imputed'] = df_imputed[col].isna()
    # Perform imputation
    df_imputed[col] = df_imputed[col].fillna(df_imputed[col].median())

# 4. Impute categorical columns with 'Not Specified'
categorical_columns = df_imputed.select_dtypes(include=['object']).columns
for col in categorical_columns:
    df_imputed[col] = df_imputed[col].fillna('Not Specified')

# Verify results
print("\nRemaining missing values after imputation:")
print(df_imputed.isna().sum())

# Show the new flag columns
flag_columns = [col for col in df_imputed.columns if col.endswith('_is_imputed')]
print("\nNew imputation flag columns:")
print(flag_columns)

# Show sample of rows where values were imputed
for col in price_columns + tech_spec_columns:
    imputed_rows = df_imputed[df_imputed[f'{col}_is_imputed']]
    if len(imputed_rows) > 0:
        print(f"\nSample of imputed values for {col}:")
        print(imputed_rows[[col, f'{col}_is_imputed']].head())
# Out:
# Remaining missing values after imputation:
# Reference Price (Yuan)                         0
# Brand                                          0
# Model                                          0
# Production Method                              0
# Origin                                         0
# Engine                                         0
# Max Horsepower (Ps)                            0
# Max Power/Speed (kW/rpm)                       0
# Transmission                                   0
# ABS                                            0
# CBS                                            0
# Dimensions (LxWxH mm)                          0
# Seat Height (mm)                               0
# Curb Weight (kg)                               0
# Fuel Tank Capacity (L)                         0
# Max Speed (km/h)                               0
# Official Average Fuel Consumption (L/100km)    0
# Range (km)                                     0
# Available Colors                               0
# Max Horsepower (Ps)_is_imputed                 0
# Seat Height (mm)_is_imputed                    0
# Curb Weight (kg)_is_imputed                    0
# Fuel Tank Capacity (L)_is_imputed              0
# Max Speed (km/h)_is_imputed                    0
# dtype: int64
#
# New imputation flag columns:
# ['Max Horsepower (Ps)_is_imputed', 'Seat Height (mm)_is_imputed', 'Curb Weight (kg)_is_imputed', 'Fuel Tank Capacity (L)_is_imputed', 'Max Speed (km/h)_is_imputed']
#
# Sample of imputed values for Max Horsepower (Ps):
#     Max Horsepower (Ps)  Max Horsepower (Ps)_is_imputed
# 23                 12.6                            True
# 44                 12.6                            True
# 63                 12.6                            True
# 77                 12.6                            True
# 78                 12.6                            True
#
# Sample of imputed values for Seat Height (mm):
#     Seat Height (mm)  Seat Height (mm)_is_imputed
# 6              770.0                         True
# 14             770.0                         True
# 17             770.0                         True
# 23             770.0                         True
# 24             770.0                         True
#
# Sample of imputed values for Curb Weight (kg):
#     Curb Weight (kg)  Curb Weight (kg)_is_imputed
# 6              130.0                         True
# 7              130.0                         True
# 14             130.0                         True
# 20             130.0                         True
# 21             130.0                         True
#
# Sample of imputed values for Fuel Tank Capacity (L):
#     Fuel Tank Capacity (L)  Fuel Tank Capacity (L)_is_imputed
# 23                     9.0                               True
# 44                     9.0                               True
# 77                     9.0                               True
# 78                     9.0                               True
# 79                     9.0                               True
#
# Sample of imputed values for Max Speed (km/h):
#     Max Speed (km/h)  Max Speed (km/h)_is_imputed
# 6               95.0                         True
# 9               95.0                         True
# 19              95.0                         True
# 30              95.0                         True
# 31              95.0                         True

# %%
df_imputed.head()
# Out:
#              Reference Price (Yuan)     Brand       Model Production Method  \
# 1  Currently no quotation available  titanium       Pedal     Not Specified
# 2  Currently no quotation available  titanium       Pedal     Not Specified
# 3  Currently no quotation available  titanium       Pedal     Not Specified
# 4  Currently no quotation available  titanium  Street car     Not Specified
# 5                             29900    Chaite  Sports car     Not Specified
#
#                        Origin  \
# 1               Not Specified
# 2               Not Specified
# 3               Not Specified
# 4               Not Specified
# 5  Jiangmen Changhua Group Co
#
#                                               Engine  Max Horsepower (Ps)  \
# 1     single cylinder four stroke water-cooled 150cc                 15.8
# 2     single cylinder four stroke water-cooled 150cc                 15.8
# 3     single cylinder four stroke water-cooled 300cc                 25.2
# 4            inline dual cylinder water-cooled 250cc                 32.6
# 5  inline dual cylinder four stroke water-cooled ...                 53.8
#
#   Max Power/Speed (kW/rpm)                                       Transmission  \
# 1                11.6/8500                                      Not Specified
# 2                11.6/8500  CVT continuously variable transmission automat...
# 3                18.5/8250  CVT continuously variable transmission automat...
# 4                  24/9500                                                  -
# 5                39.6/8500                              international 6-speed
#
#         ABS  ... Fuel Tank Capacity (L) Max Speed (km/h)  \
# 1     comes  ...                    8.0            105.0
# 2  standard  ...                    8.0            100.0
# 3  standard  ...                   11.0            118.0
# 4  standard  ...                   13.0            120.0
# 5  standard  ...                   15.0            195.0
#
#    Official Average Fuel Consumption (L/100km)  Range (km)  \
# 1                                            -           -
# 2                                            -           -
# 3                                            -           -
# 4                                            -           -
# 5                                          3.6         400
#
#           Available Colors  Max Horsepower (Ps)_is_imputed  \
# 1            Not Specified                           False
# 2  Titanium Extreme Silver                           False
# 3         Dark Night Black                           False
# 4  Titanium Extreme Silver                           False
# 5    Ice White, Track Blue                           False
#
#   Seat Height (mm)_is_imputed Curb Weight (kg)_is_imputed  \
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
# 5                       False                       False
#
#   Fuel Tank Capacity (L)_is_imputed  Max Speed (km/h)_is_imputed
# 1                             False                        False
# 2                             False                        False
# 3                             False                        False
# 4                             False                        False
# 5                             False                        False
#
# [5 rows x 24 columns]

# %%
# Save the preprocessed dataframe to checkpoints folder
df_imputed.to_csv('../data/checkpoints/imputed_full_motorcycle_data.csv', index=False)
print("Preprocessed data saved to checkpoints/preprocessed_data.csv")
# Out:
# Preprocessed data saved to checkpoints/preprocessed_data.csv

# %%
# Load the brochure motorcycle data
df_brochure = pd.read_csv('../data/formatted/brochure_motorcycle.csv')

# Drop columns with all missing values
df_brochure_cleaned = df_brochure.dropna(axis=1, how='all')

# Show info about dropped columns
dropped_cols = set(df_brochure.columns) - set(df_brochure_cleaned.columns)
print("\nColumns dropped due to all missing values:")
print(dropped_cols)

# Save the cleaned brochure dataframe
df_brochure_cleaned.to_csv('../data/checkpoints/full_brochure_motorcycle_data.csv', index=False)
print("\nCleaned brochure data saved to checkpoints/cleaned_brochure_motorcycle_data.csv")
# Out:
# Columns dropped due to all missing values:
# {'Unnamed: 42', 'Unnamed: 54', 'Tire Size(Front/Rear)', 'Container loading （CKD', 'Consumption (L/100km)', 'Unnamed: 34', 'Unnamed: 56', '(mm)', 'Wheel rim Size(Front/Rear)', 'Unnamed: 71', 'Unnamed: 82', 'Unnamed: 52', 'Unnamed: 87', 'Unnamed: 64', 'Unnamed: 45', 'Unnamed: 40', 'Unnamed: 36', 'Unnamed: 85', 'Unnamed: 49', 'parts）(PCS)', 'Unnamed: 26', 'Unnamed: 12', 'Minimum ground clearance', 'Unnamed: 62', 'Unnamed: 6', 'Container loading （SKD', 'Unnamed: 38', 'Unnamed: 19', 'Unnamed: 10', 'Unnamed: 28', 'Unnamed: 58', 'Unnamed: 76', 'Unnamed: 78', 'Unnamed: 60', 'Unnamed: 83', 'Unnamed: 75', 'Unnamed: 17', 'Unnamed: 24', 'Unnamed: 32', 'Unnamed: 4', 'Unnamed: 15', 'Unnamed: 47', 'Unnamed: 2', 'Unnamed: 30', 'Unnamed: 68', 'Unnamed: 66', 'Unnamed: 8', 'Economical Fuel', 'Unnamed: 73', 'Unnamed: 22', 'Unnamed: 80', 'packaging）(SET)'}
#
# Cleaned brochure data saved to checkpoints/cleaned_brochure_motorcycle_data.csv
