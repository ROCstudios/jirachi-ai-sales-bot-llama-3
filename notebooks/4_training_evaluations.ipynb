# %%
# Out:
# Available columns: ['Model Name', 'Reference Price (Yuan)', 'Brand', 'Model', 'Production Method', 'Origin', 'Engine', 'Max Horsepower (Ps)', 'Max Power/Speed (kW/rpm)', 'Transmission', 'ABS', 'CBS', 'Dimensions (LxWxH mm)', 'Seat Height (mm)', 'Curb Weight (kg)', 'Fuel Tank Capacity (L)', 'Max Speed (km/h)', 'Official Average Fuel Consumption (L/100km)', 'Range (km)', 'Available Colors', 'Max Horsepower (Ps)_is_imputed', 'Seat Height (mm)_is_imputed', 'Curb Weight (kg)_is_imputed', 'Fuel Tank Capacity (L)_is_imputed', 'Max Speed (km/h)_is_imputed']
#
# Sample data:
# {'Model Name': '钛极 NEXY+/未界', 'Reference Price (Yuan)': 'Currently no quotation available', 'Brand': 'titanium', 'Model': 'Pedal', 'Production Method': 'domestic', 'Origin': 'Not Specified', 'Engine': 'single cylinder four stroke water-cooled 150cc', 'Max Horsepower (Ps)': 15.8, 'Max Power/Speed (kW/rpm)': '11.6/8500', 'Transmission': 'Not Specified', 'ABS': 'CBS', 'CBS': 'Not specified', 'Dimensions (LxWxH mm)': '1970x770x1150', 'Seat Height (mm)': 765.0, 'Curb Weight (kg)': 136.0, 'Fuel Tank Capacity (L)': 8.0, 'Max Speed (km/h)': 105.0, 'Official Average Fuel Consumption (L/100km)': 'Not specified', 'Range (km)': 'Not specified', 'Available Colors': 'Not Specified', 'Max Horsepower (Ps)_is_imputed': False, 'Seat Height (mm)_is_imputed': False, 'Curb Weight (kg)_is_imputed': False, 'Fuel Tank Capacity (L)_is_imputed': False, 'Max Speed (km/h)_is_imputed': False}
#
# Debug info for BIMOTA DB1:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BIMOTA DB1
#
# Debug info for 克维思 K16-2冲 竞技版:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 克维思 K16-2冲 竞技版
#
# Debug info for 三铃 SL110T:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 三铃 SL110T
#
# Debug info for 三阳 ComBiz 125:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 三阳 ComBiz 125
#
# Debug info for 双本 速刻少女边三轮:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 双本 速刻少女边三轮
#
# Debug info for 启典 KD250-Z:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 启典 KD250-Z
#
# Debug info for 隆鑫 丽悦LX125T-50:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 隆鑫 丽悦LX125T-50
#
# Debug info for 林海 米兰阳光:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 林海 米兰阳光
#
# Debug info for BIMOTA YB10 Dieci:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BIMOTA YB10 Dieci
#
# Debug info for QJMOTOR 追700:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for QJMOTOR 追700
#
# Debug info for 轻骑 畅爽QM125-3M(III)CG:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 轻骑 畅爽QM125-3M(III)CG
#
# Debug info for 贝纳利 900Sei:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 贝纳利 900Sei
#
# Debug info for ARCH KRGT-1:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for ARCH KRGT-1
#
# Debug info for JAWA 650 Dakar:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for JAWA 650 Dakar
#
# Debug info for 春风 CFORCE 520:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 春风 CFORCE 520
#
# Debug info for VELOCETTE Venom Clubman:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for VELOCETTE Venom Clubman
#
# Debug info for 爱司卡 F02:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 爱司卡 F02
#
# Debug info for 嘉陵 好生活 JL 110-7A:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 嘉陵 好生活 JL 110-7A
#
# Debug info for 鑫源 DM250 牧羊人:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 鑫源 DM250 牧羊人
#
# Debug info for 九号 电动C系:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 九号 电动C系
#
# Debug info for BIMOTA HB4 Moto2:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BIMOTA HB4 Moto2
#
# Debug info for 台田 TT125T-8D:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 台田 TT125T-8D
#
# Debug info for 林海 福禧100:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 林海 福禧100
#
# Debug info for 嘉陵 福鹰 JL125T-16:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 嘉陵 福鹰 JL125T-16
#
# Debug info for 春风 UFORCE 800:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 春风 UFORCE 800
#
# Debug info for 豪江 劲炫天致HJ125T-19:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 豪江 劲炫天致HJ125T-19
#
# Debug info for 贝纳利 Titanium:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 贝纳利 Titanium
#
# Debug info for 赛科龙 RE600:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 赛科龙 RE600
#
# Debug info for 摩迪威 800RR:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 摩迪威 800RR
#
# Debug info for 光阳 New Many 125:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 光阳 New Many 125
#
# Debug info for 诺顿 Mercury:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 诺顿 Mercury
#
# Debug info for 力箭 LJ250B:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 力箭 LJ250B
#
# Debug info for 虔途 01:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 虔途 01
#
# Debug info for 豪爵 锐爽EN150J:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 豪爵 锐爽EN150J
#
# Debug info for 诺马 魅影 255S:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 诺马 魅影 255S
#
# Debug info for BIMOTA YB8 Furano:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BIMOTA YB8 Furano
#
# Debug info for 诺顿 Commando 961 SE:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 诺顿 Commando 961 SE
#
# Debug info for 林海 Force 领程:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 林海 Force 领程
#
# Debug info for 极核 C!TY SPORT:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 极核 C!TY SPORT
#
# Debug info for 雷拉尼 SH Pro:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 雷拉尼 SH Pro
#
# Debug info for 斐兔 FW-07:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 斐兔 FW-07
#
# Debug info for 金城 警用车JC250-6:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 金城 警用车JC250-6
#
# Debug info for 赛科龙 RA2:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 赛科龙 RA2
#
# Debug info for 卒玛 S3-T50R:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 卒玛 S3-T50R
#
# Debug info for 林海 ATV 500:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 林海 ATV 500
#
# Debug info for 克维思 K16-NC250 竞技版:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 克维思 K16-NC250 竞技版
#
# Debug info for 大阳 VPS125:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 大阳 VPS125
#
# Debug info for KAMAX TQ125:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for KAMAX TQ125
#
# Debug info for 台荣 荣150:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 台荣 荣150
#
# Debug info for 无极 350AC:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 无极 350AC
#
# Debug info for 九号 电摩N系:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 九号 电摩N系
#
# Debug info for 小牛 MT:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 小牛 MT
#
# Debug info for 南雅 NY110T-2:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 南雅 NY110T-2
#
# Debug info for MBP Feelink C150 Iron:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for MBP Feelink C150 Iron
#
# Debug info for VELOCETTE MT 500:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for VELOCETTE MT 500
#
# Debug info for GOWOW 阿尔法:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for GOWOW 阿尔法
#
# Debug info for 贝纳利 利刃150:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 贝纳利 利刃150
#
# Debug info for 五羊 喜羊羊:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 五羊 喜羊羊
#
# Debug info for 台铃 塞北:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 台铃 塞北
#
# Debug info for 亚翔 ADI450:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 亚翔 ADI450
#
# Debug info for 三铃 天王星 SL100T-6:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 三铃 天王星 SL100T-6
#
# Debug info for 北极星 横行者1000:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 北极星 横行者1000
#
# Debug info for 三铃 领航太子SL125-5BT:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 三铃 领航太子SL125-5BT
#
# Debug info for 嘉陵 CoCo:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 嘉陵 CoCo
#
# Debug info for 卒玛 ST7:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 卒玛 ST7
#
# Debug info for 飞肯 老红FK125-6G:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 飞肯 老红FK125-6G
#
# Debug info for 宗申 野米Yemi:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 宗申 野米Yemi
#
# Debug info for 鑫源 骓1200:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 鑫源 骓1200
#
# Debug info for 台田 卡拉KARLA:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 台田 卡拉KARLA
#
# Debug info for BIMOTA SB8K:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BIMOTA SB8K
#
# Debug info for JAWA 125 Dakar:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for JAWA 125 Dakar
#
# Debug info for 林海 蓝钻LH125T-18:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 林海 蓝钻LH125T-18
#
# Debug info for 银钢 铁拳 TR 250:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 银钢 铁拳 TR 250
#
# Debug info for 斗风 D1-5000W:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 斗风 D1-5000W
#
# Debug info for 欧派 米娜:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 欧派 米娜
#
# Debug info for 诺顿 Domiracer Limited Edition:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 诺顿 Domiracer Limited Edition
#
# Debug info for 凌治 MC3:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 凌治 MC3
#
# Debug info for 诺顿 Commander Rotary:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 诺顿 Commander Rotary
#
# Debug info for 欧派 布丁:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 欧派 布丁
#
# Debug info for 三阳 Joymax Z 300:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 三阳 Joymax Z 300
#
# Debug info for 爱玛 指挥官Pro:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 爱玛 指挥官Pro
#
# Debug info for BIMOTA DB9 Brivido:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BIMOTA DB9 Brivido
#
# Debug info for 轻骑 畅胜王 QM150-3P:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 轻骑 畅胜王 QM150-3P
#
# Debug info for 台田 卡拉二代KARLA125:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 台田 卡拉二代KARLA125
#
# Debug info for 银钢 小怪兽E:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 银钢 小怪兽E
#
# Debug info for 斐兔 GT-03:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 斐兔 GT-03
#
# Debug info for 永源 战隼350:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 永源 战隼350
#
# Debug info for 贝纳利 X150:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 贝纳利 X150
#
# Debug info for QJMOTOR 赛1000:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for QJMOTOR 赛1000
#
# Debug info for 天鹰 TT150公务车:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 天鹰 TT150公务车
#
# Debug info for 亚翔 AD450:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 亚翔 AD450
#
# Debug info for 鑫源 X-TRICKER(魔术师ll代):
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 鑫源 X-TRICKER(魔术师ll代)
#
# Debug info for 速珂 TC:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 速珂 TC
#
# Debug info for 银钢 Racing 400:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 银钢 Racing 400
#
# Debug info for 号外 Senmenti 0:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 号外 Senmenti 0
#
# Debug info for 银钢 大MINI:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 银钢 大MINI
#
# Debug info for 建设 JS125T-9D:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 建设 JS125T-9D
#
# Debug info for 豪爵 天鹰HJ125T-16E:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 豪爵 天鹰HJ125T-16E
#
# Debug info for 豪爵 DK150R:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 豪爵 DK150R
#
# Debug info for 钱江 MT 150:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 钱江 MT 150
#
# Debug info for QJMOTOR 追150:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for QJMOTOR 追150
#
# Debug info for 台铃 赤兔:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 台铃 赤兔
#
# Debug info for 贝纳利 BX 449 Cross:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 贝纳利 BX 449 Cross
#
# Debug info for 豪爵 DR160:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 豪爵 DR160
#
# Debug info for QJMOTOR 鸿250:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for QJMOTOR 鸿250
#
# Debug info for BIMOTA YB4 750IE:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BIMOTA YB4 750IE
#
# Debug info for 五羊 WY125T-10D:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 五羊 WY125T-10D
#
# Debug info for E客 E2 MAX:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for E客 E2 MAX
#
# Debug info for 派电 DM2:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 派电 DM2
#
# Debug info for 钛极 NEXY+/未界:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 钛极 NEXY+/未界
#
# Debug info for 台田 戈王:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 台田 戈王
#
# Debug info for 启典 KD150-K:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 启典 KD150-K
#
# Debug info for 嘉陵 嘉陵70:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 嘉陵 嘉陵70
#
# Debug info for GOGORO 1 Series:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for GOGORO 1 Series
#
# Debug info for 豪爵 DN150:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 豪爵 DN150
#
# Debug info for 天鹰 TX:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 天鹰 TX
#
# Debug info for 鑫源 欧版棍王440:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 鑫源 欧版棍王440
#
# Debug info for 豪爵 VF125:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 豪爵 VF125
#
# Debug info for 华洋 T4L:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 华洋 T4L
#
# Debug info for 天地游侠 WJ150-D:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 天地游侠 WJ150-D
#
# Debug info for QJMOTOR 追600:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for QJMOTOR 追600
#
# Debug info for 长江 Bobbie III 700i:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 长江 Bobbie III 700i
#
# Debug info for 新威骑 天行者 WR1000:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 新威骑 天行者 WR1000
#
# Debug info for 林海 LH125T-9:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 林海 LH125T-9
#
# Debug info for BIMOTA Tesi 2D Millennium:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BIMOTA Tesi 2D Millennium
#
# Debug info for 飞肯 FK125T-D:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 飞肯 FK125T-D
#
# Debug info for BIMOTA Tesi ID 851:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BIMOTA Tesi ID 851
#
# Debug info for 哈啰出行 C30:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 哈啰出行 C30
#
# Debug info for 银钢 吉虎YG150-12A:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 银钢 吉虎YG150-12A
#
# Debug info for 豪爵 KA150 HJ150-22A:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 豪爵 KA150 HJ150-22A
#
# Debug info for 诺顿 Commando 961:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 诺顿 Commando 961
#
# Debug info for SWM SM 650:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for SWM SM 650
#
# Debug info for 宗申 ZS150-38A:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 宗申 ZS150-38A
#
# Debug info for GOGORO 3 Series:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for GOGORO 3 Series
#
# Debug info for 君侉 HJ400:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 君侉 HJ400
#
# Debug info for 豪爵 虎鲨VX125:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 豪爵 虎鲨VX125
#
# Debug info for BRIXTON Sunray 125:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BRIXTON Sunray 125
#
# Debug info for 欧派 锐鹰:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 欧派 锐鹰
#
# Debug info for 哈地域骑士 GK 125:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 哈地域骑士 GK 125
#
# Debug info for 猎变 瑟:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 猎变 瑟
#
# Debug info for BIMOTA 500 V-Due Evoluzione:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BIMOTA 500 V-Due Evoluzione
#
# Debug info for 轻骑 U俠一代 QM125-3XI:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 轻骑 U俠一代 QM125-3XI
#
# Debug info for 无极 650DS:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 无极 650DS
#
# Debug info for ARCH Method 143:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for ARCH Method 143
#
# Debug info for 雷克 RX7:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 雷克 RX7
#
# Debug info for MBP S01 Comfort:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for MBP S01 Comfort
#
# Debug info for 豪江 烈兽:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 豪江 烈兽
#
# Debug info for 大运 骊影FI版-DY125T-15A:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 大运 骊影FI版-DY125T-15A
#
# Debug info for 台荣 GP1-400R:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 台荣 GP1-400R
#
# Debug info for BIMOTA HB2:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BIMOTA HB2
#
# Debug info for 小牛 C小牛 GOVA G0:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 小牛 C小牛 GOVA G0
#
# Debug info for 台铃 Y3:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 台铃 Y3
#
# Debug info for 飞肯FKM FK600 赛道版:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 飞肯FKM FK600 赛道版
#
# Debug info for 绿源 INNO5:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 绿源 INNO5
#
# Debug info for 标本 维诺拉150:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 标本 维诺拉150
#
# Debug info for 三阳 Symba 100:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 三阳 Symba 100
#
# Debug info for 赛科龙 RX1S:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 赛科龙 RX1S
#
# Debug info for QJMOTOR 迪诺:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for QJMOTOR 迪诺
#
# Debug info for 大运 STS400C:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 大运 STS400C
#
# Debug info for VELOCETTE KTT Mk VI - VIII:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for VELOCETTE KTT Mk VI - VIII
#
# Debug info for 赛科龙 RX1:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 赛科龙 RX1
#
# Debug info for 摩兽 M03:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 摩兽 M03
#
# Debug info for 北极星 RZR XP4 1000:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 北极星 RZR XP4 1000
#
# Debug info for 台荣 荣250:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 台荣 荣250
#
# Debug info for 吉铭 吉越S JM400:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 吉铭 吉越S JM400
#
# Debug info for 立田 LT125T-8H:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 立田 LT125T-8H
#
# Debug info for 松散 American Bobber:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 松散 American Bobber
#
# Debug info for 义鹰 夜莺:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 义鹰 夜莺
#
# Debug info for 欧派 星耀:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 欧派 星耀
#
# Debug info for 豪爵 DR250:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 豪爵 DR250
#
# Debug info for BIMOTA DB6R Delirio:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BIMOTA DB6R Delirio
#
# Debug info for 三阳 Jet4 50:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 三阳 Jet4 50
#
# Debug info for 皇家恩菲尔德 Bullet C5 Classic EFI:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 皇家恩菲尔德 Bullet C5 Classic EFI
#
# Debug info for JAWA 350 TS:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for JAWA 350 TS
#
# Debug info for 吉铭 坦途300:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 吉铭 坦途300
#
# Debug info for 古思特 K-01:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 古思特 K-01
#
# Debug info for 金城 灿星JC110-19V:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 金城 灿星JC110-19V
#
# Debug info for 豪江 睿御HJ100T-17:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 豪江 睿御HJ100T-17
#
# Debug info for 轻骑 逸彩QM125T-6C:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 轻骑 逸彩QM125T-6C
#
# Debug info for 可人 SRT 5:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 可人 SRT 5
#
# Debug info for 斗风 F2-3000W:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 斗风 F2-3000W
#
# Debug info for 倍思客 CL250-F:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 倍思客 CL250-F
#
# Debug info for 飞肯 超级锋驰FK110-3A:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 飞肯 超级锋驰FK110-3A
#
# Debug info for 卒玛 K5-CB250F:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 卒玛 K5-CB250F
#
# Debug info for 光阳 锋丽VP L125:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 光阳 锋丽VP L125
#
# Debug info for 三铃 SL110-6S:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 三铃 SL110-6S
#
# Debug info for 小牛 N1S:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 小牛 N1S
#
# Debug info for 三雅 逸动 SY150-47:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 三雅 逸动 SY150-47
#
# Debug info for BIMBIMOTA SB6R:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for BIMBIMOTA SB6R
#
# Debug info for 宗申 小熊:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 宗申 小熊
#
# Debug info for 速珂 Cu:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 速珂 Cu
#
# Debug info for 斗风 F1-150:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 斗风 F1-150
#
# Debug info for 台田 新悠Y:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 台田 新悠Y
#
# Debug info for 欧派 M3:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 欧派 M3
#
# Debug info for 颢晨 致炫:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 颢晨 致炫
#
# Debug info for 哈里威 神驹 500:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 哈里威 神驹 500
#
# Debug info for 飞鹰 凌雅:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 飞鹰 凌雅
#
# Debug info for 升仕 350R:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 升仕 350R
#
# Debug info for 诺马 500ADV:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 诺马 500ADV
#
# Debug info for 新感觉 XGJ250-21A:
# Dimensions: N/A
# Top Speed: N/A
# Fuel Capacity: N/A
# Engine Type: N/A
#
# Generated 0 examples for 新感觉 XGJ250-21A
#
# Total examples generated: 0
#
# Final dataset size: 0

# %%
import pandas as pd
import numpy as np
import json
import random
import os

# Part 1: Preprocessing (following notebook 2's pattern)
# Load the second motorcycle sheet
df = pd.read_csv('../data/formatted/motorcycle2_specs.csv')

# Calculate percentage of NaN values
nan_percentages = (df.isna().sum() / len(df)) * 100

# Drop columns with more than 90% NaN values
threshold = 0.9  # 90% threshold
columns_to_drop = nan_percentages[nan_percentages > 90].index
df = df.drop(columns=columns_to_drop)

# Remove rows where price is NaN
price_col = 'Reference Price (Yuan)'
initial_rows = len(df)
df = df.dropna(subset=[price_col])
rows_removed = initial_rows - len(df)

# Replace brand values less than 3 characters with 'Not Specified'
df.loc[df['Brand'].fillna('').str.len() < 3, 'Brand'] = 'Not Specified'

# Capitalize model values
df['Model'] = df['Model'].str.capitalize()

# Create imputation flags and impute missing values
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Create imputation flag columns for numeric columns with >10% missing values
for col in numeric_columns:
    if nan_percentages[col] > 10:
        flag_col = f"{col}_is_imputed"
        df[flag_col] = df[col].isna()
        df[col] = df[col].fillna(df[col].median())

# Fill categorical columns with 'Not Specified'
for col in categorical_columns:
    df[col] = df[col].fillna('Not Specified')

# Save preprocessed data
df.to_csv('../data/checkpoints/imputed_motorcycle_2_data.csv', index=False)

# Part 2: Generate Training Data (following notebook 3's pattern)
training_data = []

# Define instruction variations (using the same as in notebook 3)
instruction_variations = {
    "model_info": [
        "What can you tell me about the {model}?",
        "Give me information about the {model}.",
        "What are the specifications of the {model}?",
        "What are the main features of the {model}?",
        "Tell me about the {model}."
    ],
    "top_speed": [
        "What is the top speed of the {model}?",
        "How fast can the {model} go?",
        "Tell me the maximum speed of the {model}.",
        "What's the highest speed of the {model}?",
        "What speed can the {model} achieve?"
    ],
    "fuel_capacity": [
        "What is the fuel capacity of the {model}?",
        "How big is the fuel tank on the {model}?",
        "Tell me about the fuel tank capacity of the {model}.",
        "How much fuel can the {model} hold?",
        "What's the fuel tank size of the {model}?"
    ],
    "engine_info": [
        "What type of engine does the {model} have?",
        "Tell me about the engine in the {model}.",
        "What are the engine specifications of the {model}?",
        "What engine is in the {model}?",
        "Can you describe the engine of the {model}?"
    ]
}

input_variations = [
    "",  # Empty input for standard cases
    "Customer is interested in motorcycle performance.",
    "Customer wants to know the main features and performance.",
    "Customer asked about the motorcycle's speed and handling.",
    "Customer is looking for an overview of the motorcycle.",
    "Customer requested details on fuel and engine specs."
]

# Generate training examples
for _, row in df.iterrows():
    model = row.get('Model Name', 'Unknown Model')
    dimensions = row.get('Dimensions (LxWxH mm)', 'N/A')
    top_speed = row.get('Max Speed (km/h)', 'N/A')
    fuel_capacity = row.get('Fuel Tank Capacity (L)', 'N/A')
    engine_type = row.get('Engine', 'N/A')
    
    # Generate examples following the same pattern as notebook 3
    if not any(pd.isna([dimensions, top_speed])):
        training_data.append({
            "instruction": random.choice(instruction_variations["model_info"]).format(model=model),
            "input": random.choice(input_variations),
            "output": f"The {model} measures {dimensions}."
        })
    
    if not pd.isna(top_speed):
        training_data.append({
            "instruction": random.choice(instruction_variations["top_speed"]).format(model=model),
            "input": random.choice(input_variations),
            "output": f"The {model} has a top speed of {top_speed}{ ' km/h' if top_speed != 'Not Specified' else ''}"
        })
    
    if not pd.isna(fuel_capacity):
        training_data.append({
            "instruction": random.choice(instruction_variations["fuel_capacity"]).format(model=model),
            "input": random.choice(input_variations),
            "output": f"The fuel tank on the {model} holds {fuel_capacity}."
        })
    
    if not pd.isna(engine_type):
        training_data.append({
            "instruction": random.choice(instruction_variations["engine_info"]).format(model=model),
            "input": random.choice(input_variations),
            "output": f"The {model} comes with a {engine_type} engine."
        })

# Save training data
output_file = '../data/training/motorcycle_2_training_data.json'
with open(output_file, 'w') as f:
    json.dump(training_data, f, indent=4)

print(f"Preprocessing and training data generation complete. Files saved to:")
print(f"1. Preprocessed data: ../data/checkpoints/imputed_motorcycle_2_data.csv")
print(f"2. Training data: {output_file}")

# Convert training data to CSV format
import pandas as pd

# Convert training data list to DataFrame
df_training = pd.DataFrame(training_data)

# Save as CSV
csv_output_file = '../data/training_checkpoints/motorcycle_2_training_data.csv'
df_training.to_csv(csv_output_file, index=False)

print(f"3. Training data CSV: {csv_output_file}")
# Out:
# Preprocessing and training data generation complete. Files saved to:
# 1. Preprocessed data: ../data/checkpoints/imputed_motorcycle_2_data.csv
# 2. Training data: ../data/training/motorcycle_2_training_data.json
# 3. Training data CSV: ../data/training_checkpoints/motorcycle_2_training_data.csv
